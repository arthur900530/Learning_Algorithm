# %%
import read_data_utils as utils
import regression_weight_tuning_EU_LG_UA as EU_LG_UA
import reorganization as reorg

# %%
import sys
import copy
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

# %%
file = 'train_all_0.csv'
dataloaders, dataset_sizes = utils.read_data(file, batch_size=8, mode='mse')
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
model = nn.Sequential(
      nn.Linear(12,50),
      nn.ReLU(),
      nn.Linear(50,1)).to(device)

# model.load_state_dict(torch.load('../acceptable_weights/before_reorg.pt'))

criterion = nn.MSELoss()

train_result = EU_LG_UA.train_model(model, criterion, dataloaders, dataset_sizes, device,
                                    PATH = '../weights/train_checkpoint.pt', epsilon = 1e-6, num_epochs=50, n=8)

if train_result['result']:
    print('Acceptable SLFN')
    torch.save(model.state_dict(), '../acceptable_weights/before_reorg.pt')
#     model.load_state_dict(torch.load('../acceptable_weights/before_reorg.pt'))
    reorg_result, p = reorg.reorg_model(model, criterion, dataloaders, dataset_sizes, device, 
                                      PATH='../weights/reorg_checkpoint.pt', lr_epsilon=1e-6 , n=8, rs=0.1)
    print(reorg_result, p)
    torch.save(model.state_dict(), f'../acceptable_weights/after_reorganized_{p}.pt')
else:
    print('Unacceptable SLFN (', train_result['msg'],')')
# Out:
# Acceptable SLFN
# Break
#  ----------
# Start weight-tuning
# Finish weight-tuning
# k++
# k: 1, p: 50
# Break
#  ----------
# Start weight-tuning
# Finish weight-tuning
# p--
# k: 1, p: 49
# Reg Epoch 1/10
# ----------
# train Loss: 0.2848 Acc: 0.9625
# val Loss: 0.3702 Acc: 0.8875
# Break
#  ----------
# Start weight-tuning
# Finish weight-tuning
# p--
# k: 1, p: 48
# Break
#  ----------
# Start weight-tuning
# Finish weight-tuning
# k++
# k: 2, p: 48
# Break
#  ----------
# Start weight-tuning
# Finish weight-tuning
# p--
# k: 2, p: 47
# Break
#  ----------
# Start weight-tuning
# Finish weight-tuning
# k++
# k: 3, p: 47
# Break
#  ----------
# Start weight-tuning
# Finish weight-tuning
# k++
# k: 4, p: 47
# Break
#  ----------
# Start weight-tuning
# Finish weight-tuning
# p--
# k: 4, p: 46
# Break
#  ----------
# Start weight-tuning
# Finish weight-tuning
# k++
# k: 5, p: 46
# Reg Epoch 1/10
# ----------
# train Loss: 0.2668 Acc: 0.9625
# val Loss: 0.3707 Acc: 0.8500
# Reg Epoch 2/10
# ----------
# train Loss: 0.2612 Acc: 0.9650
# val Loss: 0.3649 Acc: 0.8500
# Reg Epoch 3/10
# ----------
# train Loss: 0.2554 Acc: 0.9600
# val Loss: 0.3583 Acc: 0.8500
# Break
#  ----------
# Start weight-tuning
# Finish weight-tuning
# k++
# k: 6, p: 46
# Break
#  ----------
# Start weight-tuning
# Finish weight-tuning
# k++
# k: 7, p: 46
# Break
#  ----------
# Start weight-tuning
# Finish weight-tuning
# k++
# k: 8, p: 46
# Break
#  ----------
# Start weight-tuning
# Finish weight-tuning
# k++
# k: 9, p: 46
# Break
#  ----------
# Start weight-tuning
# Finish weight-tuning
# k++
# k: 10, p: 46
# Break
#  ----------
# Start weight-tuning
# Finish weight-tuning
# k++
# k: 11, p: 46
# Break
#  ----------
# Start weight-tuning
# Finish weight-tuning
# k++
# k: 12, p: 46
# Break
#  ----------
# Start weight-tuning
# Finish weight-tuning
# k++
# k: 13, p: 46
# Break
#  ----------
# Start weight-tuning
# Finish weight-tuning
# k++
# k: 14, p: 46
# Break
#  ----------
# Start weight-tuning
# Finish weight-tuning
# p--
# k: 14, p: 45
# Reg Epoch 1/10
# ----------
# train Loss: 0.2329 Acc: 0.9650
# val Loss: 0.3388 Acc: 0.8750
# Reg Epoch 2/10
# ----------
# train Loss: 0.2295 Acc: 0.9650
# val Loss: 0.3361 Acc: 0.8750
# Reg Epoch 3/10
# ----------
# train Loss: 0.2261 Acc: 0.9650
# val Loss: 0.3329 Acc: 0.8750
# Reg Epoch 4/10
# ----------
# train Loss: 0.2225 Acc: 0.9625
# val Loss: 0.3293 Acc: 0.8750
# Reg Epoch 5/10
# ----------
# train Loss: 0.2188 Acc: 0.9650
# val Loss: 0.3246 Acc: 0.8750
# Reg Epoch 6/10
# ----------
# train Loss: 0.2147 Acc: 0.9650
# val Loss: 0.3201 Acc: 0.8750
# Reg Epoch 7/10
# ----------
# train Loss: 0.2102 Acc: 0.9600
# val Loss: 0.3147 Acc: 0.8750
# Reg Epoch 8/10
# ----------
# train Loss: 0.2056 Acc: 0.9575
# val Loss: 0.3104 Acc: 0.8750
# Reg Epoch 9/10
# ----------
# train Loss: 0.2010 Acc: 0.9550
# val Loss: 0.3048 Acc: 0.8750
# Reg Epoch 10/10
# ----------
# train Loss: 0.1958 Acc: 0.9550
# val Loss: 0.2979 Acc: 0.8750
# Break
#  ----------
# Start weight-tuning
# Finish weight-tuning
# k++
# k:
# Break
#  ----------
# Start weight-tuning
# Finish weight-tuning
# k++
# k: 21, p: 38
# Reg Epoch 1/10
# ----------
# train Loss: 0.1674 Acc: 0.9650
# val Loss: 0.2665 Acc: 0.8625
# Reg Epoch 2/10
# ----------
# train Loss: 0.1667 Acc: 0.9600
# val Loss: 0.2664 Acc: 0.8625
# Reg Epoch 3/10
# ----------
# train Loss: 0.1660 Acc: 0.9600
# val Loss: 0.2660 Acc: 0.8625
# Break
#  ----------
# Start weight-tuning
# Finish weight-tuning
# k++
# k: 22, p: 38
# Reg Epoch 1/10
# ----------
# train Loss: 0.1655 Acc: 0.9625
# val Loss: 0.2659 Acc: 0.8625
# Break
#  ----------
# Start weight-tuning
# Finish weight-tuning
# k++
# k: 23, p: 38
# Break
#  ----------
# Start weight-tuning
# Finish weight-tuning
# p--
# k: 23, p: 37
# Break
#  ----------
# Start weight-tuning
# Finish weight-tuning
# k++
# k: 24, p: 37
# Reg Epoch 1/10
# ----------
# train Loss: 0.1648 Acc: 0.9600
# val Loss: 0.2722 Acc: 0.8750
# Reg Epoch 2/10
# ----------
# train Loss: 0.1642 Acc: 0.9625
# val Loss: 0.2725 Acc: 0.8750
# Reg Epoch 3/10
# ----------
# train Loss: 0.1635 Acc: 0.9650
# val Loss: 0.2727 Acc: 0.8750
# Break
#  ----------
# Start weight-tuning
# Finish weight-tuning
# k++
# k: 25, p: 37
# Reg Epoch 1/10
# ----------
# train Loss: 0.1630 Acc: 0.9600
# val Loss: 0.2726 Acc: 0.8875
# Break
#  ----------
# Start weight-tuning
# Finish weight-tuning
# k++
# k: 26, p: 37
# Break
#  ----------
# Start weight-tuning
# Finish weight-tuning
# k++
# k: 27, p: 37
# Break
#  ----------
# Start weight-tuning
# Finish weight-tuning
# k++
# k: 28, p: 37
# Break
#  ----------
# Start weight-tuning
# Finish weight-tuning
# p--
# k: 28, p: 36
# Reg Epoch 1/10
# ----------
# train Loss: 0.1604 Acc: 0.9650
# val Loss: 0.2695 Acc: 0.8750
# Reg Epoch 2/10
# ----------
# train Loss: 0.1599 Acc: 0.9600
# val Loss: 0.2690 Acc: 0.8750
# Break
#  ----------
# Start weight-tuning
# Finish weight-tuning
# p--
# k: 28, p: 35
# Reg Epoch 1/10
# ----------
# train Loss: 0.1629 Acc: 0.9600
# val Loss: 0.2883 Acc: 0.8375
# Break
#  ----------
# Start weight-tuning
# Finish weight-tuning
# k++
# k: 29, p: 35
# Break
#  ----------
# Start weight-tuning
# Finish weight-tuning
# k++
# k: 30, p: 35
# Break
#  ----------
# Start weight-tuning
# Finish weight-tuning
# k++
# k: 31, p: 35
# Break
#  ----------
# Start weight-tuning
# Finish weight-tuning
# p--
# k: 31, p: 34
# Break
#  ----------
# Start weight-tuning
# Finish weight-tuning
# k++
# k: 32, p: 34
# Reg Epoch 1/10
# ----------
# train Loss: 0.1630 Acc: 0.9625
# val Loss: 0.2822 Acc: 0.8500
# Break
#  ----------
# Start weight-tuning
# Finish weight-tuning
# p--
# k: 32, p: 33
# Reg Epoch 1/10
# ----------
# train Loss: 0.1572 Acc: 0.9625
# val Loss: 0.2735 Acc: 0.8375
# Reg Epoch 2/10
# ----------
# train Loss: 0.1563 Acc: 0.9625
# val Loss: 0.2739 Acc: 0.8500
# Reg Epoch 3/10
# ----------
# train Loss: 0.1554 Acc: 0.9650
# val Loss: 0.2743 Acc: 0.8500
# Reg Epoch 4/10
# ----------
# train Loss: 0.1546 Acc: 0.9650
# val Loss: 0.2746 Acc: 0.8500
# Reg Epoch 5/10
# ----------
# train Loss: 0.1536 Acc: 0.9650
# val Loss: 0.2746 Acc: 0.8500
# Reg Epoch 6/10
# ----------
# train Loss: 0.1526 Acc: 0.9650
# val Loss: 0.2744 Acc: 0.8500
# Reg Epoch 7/10
# ----------
# train Loss: 0.1514 Acc: 0.9650
# val Loss: 0.2736 Acc: 0.8500
# Reg Epoch 8/10
# ----------
# train Loss: 0.1503 Acc: 0.9625
# val Loss: 0.2721 Acc: 0.8500
# Reg Epoch 9/10
# ----------
# train Loss: 0.1489 Acc: 0.9600
# val Loss: 0.2697 Acc: 0.8500
# Reg Epoch 10/10
# ----------
# train Loss: 0.1475 Acc: 0.9625
# val Loss: 0.2699 Acc: 0.8500
# Break
#  ----------
# Start weight-tuning
# Finish weight-tuning
# p--
# k: 32, p: 32
# <All keys matched successfully> 32
