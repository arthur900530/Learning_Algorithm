# %%
import read_data_utils as utils
import regression_weight_tuning_EU_LG_UA as EU_LG_UA
import reorganization as reorg

# %%
import sys
import copy
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

# %%
file = 'train_all_0.csv'
dataloaders, dataset_sizes = utils.read_data(file, batch_size=4, mode='mse')
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
model = nn.Sequential(
      nn.Linear(12,128),
      nn.ReLU(),
      nn.Linear(128,1)).to(device)

# model.load_state_dict(torch.load('../acceptable_weights/before_reorg.pt'))

criterion = nn.MSELoss()

train_result = EU_LG_UA.train_model(model, criterion, dataloaders, dataset_sizes, device,
                                    PATH = '../weights/train_checkpoint.pt', epsilon = 1e-8, num_epochs=50, n=10)

if train_result['result']:
    torch.save(model.state_dict(), '../acceptable_weights/before_reorg.pt')
#     model.load_state_dict(torch.load('../acceptable_weights/before_reorg.pt'))
    reorg_result, p = reorg.reorg_model(model, criterion, dataloaders, dataset_sizes, device, 
                                      PATH='../weights/reorg_checkpoint.pt', lr_epsilon=1e-8 , n=10, rs=0.001)
print(reorg_result, p)
torch.save(result, f'../acceptable_weights/after_reorganized_{p}.pt')
# Out:
# Reg Epoch 1/10
# ----------
# train Loss: 0.0556 Acc: 0.9525
# val Loss: 0.2697 Acc: 0.9000
# Reg Epoch 2/10
# ----------
# train Loss: 0.0552 Acc: 0.9525
# val Loss: 0.2871 Acc: 0.9000
# Reg Epoch 3/10
# ----------
# train Loss: 0.0552 Acc: 0.9550
# val Loss: 0.2736 Acc: 0.9000
# Reg Epoch 4/10
# ----------
# train Loss: 0.0551 Acc: 0.9550
# val Loss: 0.2880 Acc: 0.9000
# Reg Epoch 5/10
# ----------
# train Loss: 0.0549 Acc: 0.9525
# val Loss: 0.2956 Acc: 0.9000
# Reg Epoch 6/10
# ----------
# train Loss: 0.0549 Acc: 0.9550
# val Loss: 0.2899 Acc: 0.9000
# Reg Epoch 7/10
# ----------
# train Loss: 0.0547 Acc: 0.9550
# val Loss: 0.2939 Acc: 0.9000
# Reg Epoch 8/10
# ----------
# train Loss: 0.0546 Acc: 0.9525
# val Loss: 0.2919 Acc: 0.9000
# Reg Epoch 9/10
# ----------
# train Loss: 0.0544 Acc: 0.9500
# val Loss: 0.2834 Acc: 0.9000
# Reg Epoch 10/10
# ----------
# train Loss: 0.0542 Acc: 0.9550
# val Loss: 0.2843 Acc: 0.9000
# Start weight-tuning
# Finish weight-tuning
# p--
# k: 0, p: 127
# Reg Epoch 1/10
# ----------
# train Loss: 0.0536 Acc: 0.9575
# val Loss: 0.2845 Acc: 0.9000
# Reg Epoch 2/10
# ----------
# train Loss: 0.0536 Acc: 0.9575
# val Loss: 0.2845 Acc: 0.9000
# Break
#  ----------
# Start weight-tuning
# Finish weight-tuning
# p--
# k: 0, p: 126
# Reg Epoch 1/10
# ----------
# train Loss: 0.0539 Acc: 0.9600
# val Loss: 0.3268 Acc: 0.9000
# Break
#  ----------
# Start weight-tuning
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [5], in <cell line: 15>()
#      17 #     model.load_state_dict(torch.load('../acceptable_weights/before_reorg.pt'))
#      18     optimizer = torch.optim.SGD(model.parameters(), lr=1e-3)
# ---> 19     reorg_result, p = reorg.reorg_model(model, criterion, optimizer, dataloaders, dataset_sizes, device,
#      20                                       PATH='../weights/reorg_checkpoint.pt', lr_epsilon=1e-8 , n=10, rs=0.001)
#      21 print(reorg_result, p)
#      22 torch.save(result, f'../acceptable_weights/after_reorganized_{p}.pt')
#
# File ~\pycharm-work-place\新演\src\reorganization.py:235, in reorg_model(model, criterion, optimizer, dataloaders, dataset_sizes, device, PATH, lr_epsilon, n, rs)
#     233 model.load_state_dict(msd)
#     234 print('Start weight-tuning')
# --> 235 result = EU_LG_UA.train_model(model, criterion, optimizer,
#     236                               dataloaders, dataset_sizes, device,
#     237                               epsilon=lr_epsilon, num_epochs=50, n=n, show=False)
#     238 print('Finish weight-tuning')
#     239 if result['result']:
#
# File ~\pycharm-work-place\新演\src\regression_weight_tuning_EU_LG_UA.py:71, in train_model(model, criterion, optimizer, dataloaders, dataset_sizes, device, PATH, epsilon, num_epochs, n, show)
#      69 corrects = 0
#      70 # Iterate over data
# ---> 71 for inputs, labels in dataloaders[phase]:
#      72     s = inputs.size(0)
#      73     inputs = inputs.to(device)
#
# File ~\anaconda3\envs\pytorch10\lib\site-packages\torch\utils\data\dataloader.py:530, in _BaseDataLoaderIter.__next__(self)
#     528 if self._sampler_iter is None:
#     529     self._reset()
# --> 530 data = self._next_data()
#     531 self._num_yielded += 1
#     532 if self._dataset_kind == _DatasetKind.Iterable and \
#     533         self._IterableDataset_len_called is not None and \
#     534         self._num_yielded > self._IterableDataset_len_called:
#
# File ~\anaconda3\envs\pytorch10\lib\site-packages\torch\utils\data\dataloader.py:1207, in _MultiProcessingDataLoaderIter._next_data(self)
#    1204     return self._process_data(data)
#    1206 assert not self._shutdown and self._tasks_outstanding > 0
# -> 1207 idx, data = self._get_data()
#    1208 self._tasks_outstanding -= 1
#    1209 if self._dataset_kind == _DatasetKind.Iterable:
#    1210     # Check for _IterableDatasetStopIteration
#
# File ~\anaconda3\envs\pytorch10\lib\site-packages\torch\utils\data\dataloader.py:1173, in _MultiProcessingDataLoaderIter._get_data(self)
#    1169     # In this case, `self._data_queue` is a `queue.Queue`,. But we don't
#    1170     # need to call `.task_done()` because we don't use `.join()`.
#    1171 else:
#    1172     while True:
# -> 1173         success, data = self._try_get_data()
#    1174         if success:
#    1175             return data
#
# File ~\anaconda3\envs\pytorch10\lib\site-packages\torch\utils\data\dataloader.py:1011, in _MultiProcessingDataLoaderIter._try_get_data(self, timeout)
#     998 def _try_get_data(self, timeout=_utils.MP_STATUS_CHECK_INTERVAL):
#     999     # Tries to fetch data from `self._data_queue` once for a given timeout.
#    1000     # This can also be used as inner loop of fetching without timeout, with
#    (...)
#    1008     # Returns a 2-tuple:
#    1009     #   (bool: whether successfully get data, any: data if successful else None)
#    1010     try:
# -> 1011         data = self._data_queue.get(timeout=timeout)
#    1012         return (True, data)
#    1013     except Exception as e:
#    1014         # At timeout and error, we manually check whether any worker has
#    1015         # failed. Note that this is the only mechanism for Windows to detect
#    1016         # worker failures.
#
# File ~\anaconda3\envs\pytorch10\lib\multiprocessing\queues.py:107, in Queue.get(self, block, timeout)
#     105 if block:
#     106     timeout = deadline - time.monotonic()
# --> 107     if not self._poll(timeout):
#     108         raise Empty
#     109 elif not self._poll():
#
# File ~\anaconda3\envs\pytorch10\lib\multiprocessing\connection.py:257, in _ConnectionBase.poll(self, timeout)
#     255 self._check_closed()
#     256 self._check_readable()
# --> 257 return self._poll(timeout)
#
# File ~\anaconda3\envs\pytorch10\lib\multiprocessing\connection.py:330, in PipeConnection._poll(self, timeout)
#     327 if (self._got_empty_message or
#     328             _winapi.PeekNamedPipe(self._handle)[0] != 0):
#     329     return True
# --> 330 return bool(wait([self], timeout))
#
# File ~\anaconda3\envs\pytorch10\lib\multiprocessing\connection.py:879, in wait(object_list, timeout)
#     876                 ready_objects.add(o)
#     877                 timeout = 0
# --> 879     ready_handles = _exhaustive_wait(waithandle_to_obj.keys(), timeout)
#     880 finally:
#     881     # request that overlapped reads stop
#     882     for ov in ov_list:
#
# File ~\anaconda3\envs\pytorch10\lib\multiprocessing\connection.py:811, in _exhaustive_wait(handles, timeout)
#     809 ready = []
#     810 while L:
# --> 811     res = _winapi.WaitForMultipleObjects(L, False, timeout)
#     812     if res == WAIT_TIMEOUT:
#     813         break
#
# KeyboardInterrupt:
